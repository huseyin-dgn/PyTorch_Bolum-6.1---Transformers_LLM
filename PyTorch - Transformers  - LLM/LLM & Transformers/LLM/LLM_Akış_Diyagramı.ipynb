# %% [markdown]
# ```python
# ╔══════════════╗
# ║  Ham Metin   ║
# ╚══════╦═══════╝
#        │
#        v
# ╔══════════════╗
# ║  Tokenizer   ║
# ║ (Subword/BPE)║
# ╚══════╦═══════╝
#        │
#        v
# ╔════════════════════════╗
# ║ Input IDs & Attention  ║
# ║       Masks           ║
# ╚══════╦════════════════╝
#        │
#        v
# ╔════════════════════════╗
# ║   Model Forward Pass   ║
# ║      (LLM: Encoder-   ║
# ║       Decoder veya     ║
# ║       Decoder-only)    ║
# ╚══════╦════════════════╝
#        │
#        v
# ╔════════════════════════╗
# ║    Loss Hesaplama      ║
# ║ - CrossEntropy         ║
# ║ - Padding Mask         ║
# ║ - Label Smoothing      ║
# ╚══════╦════════════════╝
#        │
#        v
# ╔════════════════════════╗
# ║  Backpropagation       ║
# ║ (Gradients Hesaplama) ║
# ╚══════╦════════════════╝
#        │
#        v
# ╔════════════════════════╗
# ║ Optimizer Step          ║
# ║ (AdamW / Adafactor)     ║
# ╚══════╦════════════════╝
#        │
#        v
# ╔════════════════════════╗
# ║ Scheduler Step          ║
# ║ (LR Adjustment)         ║
# ╚══════╦════════════════╝
#        │
#        v
# ╔════════════════════════╗
# ║ Metrics Hesaplama       ║
# ║ - Token-level: Accuracy ║
# ║   Perplexity           ║
# ║ - Sequence-level: BLEU,║
# ║   ROUGE, F1            ║
# ╚══════╦════════════════╝
#        │
#        v
# ╔════════════════════════╗
# ║      Epoch Sonu         ║
# ╚══════╦════════════════╝
#        │
#        v
# ╔════════════════════════╗
# ║ Bir Sonraki Epoch?      ║
# ╚══════╦════════════════╝
#        │
#    ┌───┴───┐
#    │       │
#   Evet     Hayır
#    │       │
#    v       v
#  Input IDs Eğitim Tamamlandı

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\hdgn5\OneDrive\Masaüstü\PyTorch - Transformers  - LLM\LLM & Transformers\Diyagram.png")

plt.figure(figsize=(16, 12))  # Genişlik 16, yükseklik 12 inç olarak ayarlandı
plt.imshow(img)
plt.axis('off')
plt.show()
